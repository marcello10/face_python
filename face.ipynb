# %%
import cv2
import ultralytics
from ultralytics import YOLO

# %%
# Load the YOLO model
#https://github.com/akanametov/yolo-face?tab=readme-ov-file
model = YOLO("yolov11n-face.pt")

# Open the video file

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)

    for result in results:
        boxes = result.boxes.xyxy  # Coordenadas das caixas delimitadoras
        scores = result.boxes.conf  # Confiabilidade
        labels = result.boxes.cls  # Classes

        for box, score, label in zip(boxes, scores, labels):
            if label == 0 and score > 0.5:  # A classe '0' geralmente é para pessoas/rostos em modelos pré-treinados
                x1, y1, x2, y2 = map(int, box)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, 'face', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow('Webcam', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 face, 63.0ms
# Speed: 16.1ms preprocess, 63.0ms inference, 88.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.8ms
# ...

# %%
results[0][1].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.6453], device='cuda:0')
# data: tensor([[245.0086, 257.0662, 290.5022, 320.6680,   0.6453,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[267.7554, 288.8671,  45.4935,  63.6019]], device='cuda:0')
# xywhn: tensor([[0.4184, 0.6018, 0.0711, 0.1325]], device='cuda:0')
# xyxy: tensor([[245.0086, 257.0662, 290.5022, 320.6680]], device='cuda:0')
# xyxyn: tensor([[0.3828, 0.5356, 0.4539, 0.6681]], device='cuda:0')

# %%
results = model("https://ultralytics.com/images/bus.jpg")
for r in results:
    print(f"Detected {len(r)} objects in image")
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 c:\Users\Marcelo\Documents\d2l-en\pytorch\bus.jpg: 640x480 2 faces, 26.7ms
# Speed: 6.9ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected 2 objects in image
